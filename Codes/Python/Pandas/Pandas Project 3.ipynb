# %%
import numpy as np
import pandas as pd

# %%
# Read the Retail dataset with header information
infile = "C:\\Users\\SONY\\Pandas Project\\Retail.csv"
retail_df = pd.read_csv(infile, delimiter = ",")
retail_df.head()
# Out:
# <bound method NDFrame.head of              Region         Product    Subsidiary  Stores     Sales  \
# 0            Africa            Boot   Addis Ababa      12   29761.0
# 1            Africa    Men's Casual   Addis Ababa       4   67242.0
# 2            Africa     Men's Dress   Addis Ababa       7   76793.0
# 3            Africa          Sandal   Addis Ababa      10   62819.0
# 4            Africa         Slipper   Addis Ababa      14   68641.0
# 5            Africa      Sport Shoe   Addis Ababa       4    1690.0
# 6            Africa  Women's Casual   Addis Ababa       2   51541.0
# 7            Africa   Women's Dress   Addis Ababa      12  108942.0
# 8            Africa            Boot       Algiers      21   21297.0
# 9            Africa    Men's Casual       Algiers       4   63206.0
# 10           Africa     Men's Dress       Algiers      13  123743.0
# 11           Africa          Sandal       Algiers      25   29198.0
# 12           Africa         Slipper       Algiers      17   64891.0
# 13           Africa      Sport Shoe       Algiers       9    2617.0
# 14           Africa   Women's Dress       Algiers      12   90648.0
# 15           Africa            Boot         Cairo      20    4846.0
# 16           Africa    Men's Casual         Cairo      25  360209.0
# 17           Africa     Men's Dress         Cairo       5    4051.0
# 18           Africa          Sandal         Cairo       9   10532.0
# 19           Africa         Slipper         Cairo       9   13732.0
# 20           Africa      Sport Shoe         Cairo       3    2259.0
# 21           Africa  Women's Casual         Cairo      14  328474.0
# 22           Africa   Women's Dress         Cairo       3   14095.0
# 23           Africa            Boot  Johannesburg      14    8365.0
# 24           Africa          Sandal  Johannesburg      13   17337.0
# 25           Africa         Slipper  Johannesburg      12   39452.0
# 26           Africa      Sport Shoe  Johannesburg       8    5172.0
# 27           Africa   Women's Dress  Johannesburg       4   42682.0
# 28           Africa            Boot      Khartoum      24   19282.0
# 29           Africa    Men's Casual      Khartoum       1    9244.0
# ..              ...             ...           ...     ...       ...
# 365  Western Europe            Boot        London      31   54449.0
# 366  Western Europe    Men's Casual        London      13  151402.0
# 367  Western Europe     Men's Dress        London      13  151458.0
# 368  Western Europe          Sandal        London       2    5217.0
# 369  Western Europe         Slipper        London      14  172002.0
# 370  Western Europe      Sport Shoe        London      10    9165.0
# 371  Western Europe  Women's Casual        London       5   68962.0
# 372  Western Europe   Women's Dress        London      25  149354.0
# 373  Western Europe            Boot        Madrid       1    1179.0
# 374  Western Europe    Men's Casual        Madrid       4   71014.0
# 375  Western Europe     Men's Dress        Madrid       4   54791.0
# 376  Western Europe         Slipper        Madrid       4   12127.0
# 391   132283.0   1829.0
# 392    74848.0    549.0
# 393    62256.0    954.0
# 394   389861.0   3160.0
#
# [395 rows x 7 columns]>

# %%
# Read the Retail India dataset with header information
infile = "C:\\Users\\SONY\\Pandas Project\\Retail_India.csv"
retail_india_df = pd.read_csv(infile, delimiter = ",")
retail_india_df
# Out:
#   Region         Product Subsidiary  Stores  Sales  Inventory  Returns
# 0   Asia            Boot      India       1   1996       9576       80
# 1   Asia     Men's Dress      India       1   3033      20831       52
# 2   Asia          Sandal      India       1   3230      15087      120
# 3   Asia         Slipper      India       1   3019      16075      127
# 4   Asia  Women's Casual      India       1   5389      16251      185

# %%
# Append the Retail India Products to main dataframe
retail_df = retail_df.append(retail_india_df).reset_index(drop = True)
retail_df.tail(10)
# Out:
#              Region         Product Subsidiary  Stores     Sales  Inventory  \
# 390  Western Europe          Sandal       Rome       3    1249.0     4611.0
# 391  Western Europe         Slipper       Rome      13   42442.0   132283.0
# 392  Western Europe      Sport Shoe       Rome      14    9969.0    74848.0
# 393  Western Europe  Women's Casual       Rome       2   19964.0    62256.0
# 394  Western Europe   Women's Dress       Rome      16  106676.0   389861.0
# 395            Asia            Boot      India       1    1996.0     9576.0
# 396            Asia     Men's Dress      India       1    3033.0    20831.0
# 397            Asia          Sandal      India       1    3230.0    15087.0
# 398            Asia         Slipper      India       1    3019.0    16075.0
# 399            Asia  Women's Casual      India       1    5389.0    16251.0
#
#      Returns
# 390     48.0
# 391   1829.0
# 392    549.0
# 393    954.0
# 394   3160.0
# 395     80.0
# 396     52.0
# 397    120.0
# 398    127.0
# 399    185.0

# %%
# Default plot using Pandas 
retail_df.plot()
import matplotlib.pyplot as plt
plt.show()

# %%
# Ploting single variable from Pandas Dataframe
retail_df.Sales.plot()

# %%
# Bar chart for Sales variable
retail_df.Sales.plot.bar()
plt.show()

# %%
# Bar Chartfor each region on X-axis
# retail_df.Sales.plot.bar(x = 'Region')
# plt.show()

# Aggregate the Salesat Regional level
retail_aggr = pd.DataFrame(retail_df.groupby("Region").Sales.sum())
retail_aggr.head(5)

retail_aggr.Sales.plot.bar(x = 'Region')
plt.show()

# %%
# Scatter Plot between Sales and Returns
retail_df.plot.scatter(x = "Sales", y = "Returns")
plt.show()

y = f(x)
returns = f(sales)
returns = a+b*sales

# %%
# Histogram for Sales
retail_df.Sales.plot.hist()
plt.show()

# %%
# Histogram for each numeric columns
retail_df.hist(column = ["Sales","Returns","Inventory"])
plt.show()

# %%
# Box Plot for each numerix columns
retail_df.plot.box()
plt.show()
