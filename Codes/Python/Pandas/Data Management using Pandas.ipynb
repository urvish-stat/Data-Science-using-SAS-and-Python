# %% [markdown]
# # Data Management using Pandas

# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Urvish\\Data Science using SAS and Python\\Pandas'

# %%
# Read the Retail dataset with header information
infile = "C:\\Users\\Urvish\\Data Science using SAS and Python\\Data\\Retail.csv"
retail_df = pd.read_csv(infile, delimiter = ",")
retail_df
# Out:
#              Region         Product   Subsidiary  Stores     Sales  Inventory  \
# 0            Africa            Boot  Addis Ababa      12   29761.0   191821.0
# 1            Africa    Men's Casual  Addis Ababa       4   67242.0   118036.0
# 2            Africa     Men's Dress  Addis Ababa       7   76793.0   136273.0
# 3            Africa          Sandal  Addis Ababa      10   62819.0   204284.0
# 4            Africa         Slipper  Addis Ababa      14   68641.0   279795.0
# ..              ...             ...          ...     ...       ...        ...
# 390  Western Europe          Sandal         Rome       3    1249.0     4611.0
# 391  Western Europe         Slipper         Rome      13   42442.0   132283.0
# 392  Western Europe      Sport Shoe         Rome      14    9969.0    74848.0
# 393  Western Europe  Women's Casual         Rome       2   19964.0    62256.0
# 394  Western Europe   Women's Dress         Rome      16  106676.0   389861.0
#
#      Returns
# 0      769.0
# ...

# %%
# Read the Retail dataset without header
infile = "C:\\Users\\Urvish\\Data Science using SAS and Python\\Data\\Retail_Without_Header.csv"
col_names = ["Region", "Product", "Subsidiary", "Stores", "Sales", "Inventory", "Returns"]
retail_df1 = pd.read_csv(infile, delimiter = ",", names = col_names)
retail_df1
# Out:
#              Region         Product   Subsidiary  Stores     Sales  Inventory  \
# 0            Africa            Boot  Addis Ababa      12   29761.0   191821.0
# 1            Africa    Men's Casual  Addis Ababa       4   67242.0   118036.0
# 2            Africa     Men's Dress  Addis Ababa       7   76793.0   136273.0
# 3            Africa          Sandal  Addis Ababa      10   62819.0   204284.0
# 4            Africa         Slipper  Addis Ababa      14   68641.0   279795.0
# ..              ...             ...          ...     ...       ...        ...
# 390  Western Europe          Sandal         Rome       3    1249.0     4611.0
# 391  Western Europe         Slipper         Rome      13   42442.0   132283.0
# 392  Western Europe      Sport Shoe         Rome      14    9969.0    74848.0
# 393  Western Europe  Women's Casual         Rome       2   19964.0    62256.0
# 394  Western Europe   Women's Dress         Rome      16  106676.0   389861.0
#
#      Returns
# 0      769.0
# ...

# %%
# Display first 5 products
retail_df.head()
# Out:
#    Region       Product   Subsidiary  Stores    Sales  Inventory  Returns
# 0  Africa          Boot  Addis Ababa      12  29761.0   191821.0    769.0
# 1  Africa  Men's Casual  Addis Ababa       4  67242.0   118036.0   2284.0
# 2  Africa   Men's Dress  Addis Ababa       7  76793.0   136273.0   2433.0
# 3  Africa        Sandal  Addis Ababa      10  62819.0   204284.0   1861.0
# 4  Africa       Slipper  Addis Ababa      14  68641.0   279795.0   1771.0

# %%
# Display last 5 products 
retail_df.tail()
# Out:
#              Region         Product Subsidiary  Stores     Sales  Inventory  \
# 390  Western Europe          Sandal       Rome       3    1249.0     4611.0
# 391  Western Europe         Slipper       Rome      13   42442.0   132283.0
# 392  Western Europe      Sport Shoe       Rome      14    9969.0    74848.0
# 393  Western Europe  Women's Casual       Rome       2   19964.0    62256.0
# 394  Western Europe   Women's Dress       Rome      16  106676.0   389861.0
#
#      Returns
# 390     48.0
# 391   1829.0
# 392    549.0
# 393    954.0
# 394   3160.0

# %%
# Take a random sample of 10 products
prod_sample = retail_df.sample(10)
prod_sample
# Out:
#                         Region         Product   Subsidiary  Stores     Sales  \
# 73                      Canada         Slipper      Calgary       2    5676.0
# 151             Eastern Europe      Sport Shoe       Moscow      23   21464.0
# 311              United States     Men's Dress  Minneapolis      22  235842.0
# 101                     Canada     Men's Dress    Vancouver      28  757798.0
# 34                      Africa  Women's Casual     Khartoum       1   19582.0
# 103                     Canada         Slipper    Vancouver      27  700513.0
# 336             Western Europe         Slipper   Copenhagen       4   15908.0
# 169             Eastern Europe   Women's Dress       Warsaw      19  108936.0
# 110  Central America/Caribbean          Sandal     Kingston      15  200156.0
# 374             Western Europe    Men's Casual       Madrid       4   71014.0
#
#      Inventory  Returns
# 73     48061.0    253.0
# 151   110822.0    859.0
# 311   623645.0   7344.0
# ...

# %%
# Get the top 5 products in terms of returns for region/subsidairy/stores
by_vars = ["Returns"]
returns = retail_df.sort_values(by = by_vars, ascending = False)[["Region", "Product", "Subsidiary", "Stores", "Returns"]]
returns.head()
# Out:
#                         Region        Product Subsidiary  Stores  Returns
# 187                Middle East   Men's Casual   Tel Aviv      11  57362.0
# 103                     Canada        Slipper  Vancouver      27  21247.0
# 100                     Canada   Men's Casual  Vancouver      25  20470.0
# 108  Central America/Caribbean   Men's Casual   Kingston      28  20005.0
# 106                     Canada  Women's Dress  Vancouver      21  19378.0

# %%
# Analyze the products with returns greater than 20000 across region/subsidairy/stores
returns = returns[returns.Returns > 20000.00]
returns
# Out:
#                         Region       Product Subsidiary  Stores  Returns
# 187                Middle East  Men's Casual   Tel Aviv      11  57362.0
# 103                     Canada       Slipper  Vancouver      27  21247.0
# 100                     Canada  Men's Casual  Vancouver      25  20470.0
# 108  Central America/Caribbean  Men's Casual   Kingston      28  20005.0

# %%
# Calculate the sum and mean of sales, returns and inventory across region/subsidairy
groupby_vars = ["Region", "Subsidiary"]
retail_aggr = retail_df.groupby(groupby_vars).sum()
retail_aggr["mean_sales"] = retail_df.groupby(groupby_vars).mean().Sales
retail_aggr["mean_inventory"] = retail_df.groupby(groupby_vars).mean().Inventory
retail_aggr["mean_returns"] = retail_df.groupby(groupby_vars).mean().Returns
retail_aggr["total_stores"] = retail_df.groupby(groupby_vars).count().Stores
retail_aggr.round(2)
# Out:
#                                         Stores      Sales  Inventory  \
# Region                    Subsidiary
# Africa                    Addis Ababa       65   467429.0  1356501.0
#                           Algiers          101   395600.0  1212116.0
#                           Cairo             88   738198.0  2245536.0
#                           Johannesburg      51   113008.0   375534.0
#                           Khartoum          71   186592.0   588019.0
#                           Kinshasa          56   196816.0   591284.0
#                           Luanda            30   138115.0   436277.0
#                           Nairobi           70   106830.0   295806.0
# Asia                      Bangkok            5    16667.0    77820.0
#                           Seoul             59   442409.0  1082717.0
#                           Tokyo              1     1155.0    15602.0
# Canada                    Calgary           29    61403.0   259578.0
# ...

# %%
# Calculate the total sales, total returns and total inventory across region
groupby_vars = ["Region"]
retail_aggr = retail_df.groupby(groupby_vars).sum()
retail_aggr["mean_sales"] = retail_df.groupby(groupby_vars).mean().Sales
retail_aggr["mean_inventory"] = retail_df.groupby(groupby_vars).mean().Inventory
retail_aggr["mean_returns"] = retail_df.groupby(groupby_vars).mean().Returns
retail_aggr["total_stores"] = retail_df.groupby(groupby_vars).count().Stores

# Sort the Regional returns in descending order 
by_vars = ["Returns"]
retail_aggr = retail_aggr.sort_values(by = by_vars, ascending = False)
retail_aggr.round(2)
# Out:
#                            Stores      Sales   Inventory   Returns  \
# Region
# Middle East                   397  5631779.0  14208749.0  206880.0
# United States                 617  5503986.0  16582397.0  187502.0
# Western Europe                642  4873000.0  14842250.0  169755.0
# Canada                        442  4255712.0  13110709.0  129394.0
# Central America/Caribbean     539  3657753.0  10173878.0  126898.0
# South America                 632  2434783.0   5986094.0  102851.0
# Eastern Europe                379  2394940.0   7952471.0   86701.0
# Pacific                       356  2296794.0   7971291.0   77129.0
# Africa                        532  2342588.0   7101073.0   74087.0
# Asia                           65   460231.0   1176139.0   10895.0
#
#                            mean_sales  mean_inventory  mean_returns  \
# Region
# Middle East                 234657.46       592031.21       8620.00
# United States               137599.65       414559.92       4687.55
# ...

# %%
def util_retail_aggr(in_dfn,analysis_vars,group_vars):
    
    "This function will agreegate the specific measures at given supplied hierarchy"
  
    print("Input Dataframe Name = ", in_dfn.name)
    print("Analysis Variables = ", analysis_vars)
    print("Grouping Variables = ", group_vars)    
    
    global retail_aggr
    
    if str(analysis_vars).upper() == "ALL":        
        retail_aggr = in_dfn.groupby(group_vars).sum()

    else:                    
        for key,value in in_dfn.iteritems():
            if key in analysis_vars:   
                var = [key]
                name = "mean_"+str(key)
                print(name)
                keep_vars = var + group_vars
                _temp_df = in_dfn[keep_vars]
                retail_aggr[name] = _temp_df.groupby(group_vars).mean()          
        
    return retail_aggr

# %%
# Specify the Name for Dataframe
retail_df.name = "Retail Dataframe"

# Get the Total/Sum of all the numeric variables across Region and Subsidiary from retail Dataframe
util_retail_aggr(in_dfn = retail_df, analysis_vars = "All", group_vars = ["Region","Subsidiary"])
# Out:
# Input Dataframe Name =  Retail Dataframe
# Analysis Variables =  All
# Grouping Variables =  ['Region', 'Subsidiary']
#                                         Stores      Sales  Inventory   Returns
# Region                    Subsidiary
# Africa                    Addis Ababa       65   467429.0  1356501.0   13370.0
#                           Algiers          101   395600.0  1212116.0   12763.0
#                           Cairo             88   738198.0  2245536.0   22477.0
#                           Johannesburg      51   113008.0   375534.0    3962.0
#                           Khartoum          71   186592.0   588019.0    7051.0
#                           Kinshasa          56   196816.0   591284.0    5582.0
#                           Luanda            30   138115.0   436277.0    4328.0
#                           Nairobi           70   106830.0   295806.0    4554.0
# Asia                      Bangkok            5    16667.0    77820.0     564.0
# ...

# %%
# Get the Mean of Sales and Returns across Region and Subsidiary from Retail Dataframe
util_retail_aggr(in_dfn = retail_df, analysis_vars = ["Sales","Returns"], group_vars = ["Region","Subsidiary"])
retail_aggr.round(2)
# Out:
# Input Dataframe Name =  Retail Dataframe
# Analysis Variables =  ['Sales', 'Returns']
# Grouping Variables =  ['Region', 'Subsidiary']
# mean_Sales
# mean_Returns
#                                         Stores      Sales  Inventory  \
# Region                    Subsidiary
# Africa                    Addis Ababa       65   467429.0  1356501.0
#                           Algiers          101   395600.0  1212116.0
#                           Cairo             88   738198.0  2245536.0
#                           Johannesburg      51   113008.0   375534.0
#                           Khartoum          71   186592.0   588019.0
#                           Kinshasa          56   196816.0   591284.0
#                           Luanda            30   138115.0   436277.0
#                           Nairobi           70   106830.0   295806.0
# Asia                      Bangkok            5    16667.0    77820.0
#                           Seoul             59   442409.0  1082717.0
# ...

# %%
# Get the Total/Sum of all the numeric variables across Region from retail Dataframe
util_retail_aggr(in_dfn = retail_df, analysis_vars = "All", group_vars = ["Region"])
# Out:
# Input Dataframe Name =  Retail Dataframe
# Analysis Variables =  All
# Grouping Variables =  ['Region']
#                            Stores      Sales   Inventory   Returns
# Region
# Africa                        532  2342588.0   7101073.0   74087.0
# Asia                           65   460231.0   1176139.0   10895.0
# Canada                        442  4255712.0  13110709.0  129394.0
# Central America/Caribbean     539  3657753.0  10173878.0  126898.0
# Eastern Europe                379  2394940.0   7952471.0   86701.0
# Middle East                   397  5631779.0  14208749.0  206880.0
# Pacific                       356  2296794.0   7971291.0   77129.0
# South America                 632  2434783.0   5986094.0  102851.0
# United States                 617  5503986.0  16582397.0  187502.0
# Western Europe                642  4873000.0  14842250.0  169755.0

# %%
# Get the Mean of Sales and Returns across Region and Subsidiary from Retail Dataframe
util_retail_aggr(in_dfn = retail_df, analysis_vars = ["Sales","Returns"], group_vars = ["Region"])
retail_aggr.round(2)
# Out:
# Input Dataframe Name =  Retail Dataframe
# Analysis Variables =  ['Sales', 'Returns']
# Grouping Variables =  ['Region']
# mean_Sales
# mean_Returns
#                            Stores      Sales   Inventory   Returns  \
# Region
# Africa                        532  2342588.0   7101073.0   74087.0
# Asia                           65   460231.0   1176139.0   10895.0
# Canada                        442  4255712.0  13110709.0  129394.0
# Central America/Caribbean     539  3657753.0  10173878.0  126898.0
# Eastern Europe                379  2394940.0   7952471.0   86701.0
# Middle East                   397  5631779.0  14208749.0  206880.0
# Pacific                       356  2296794.0   7971291.0   77129.0
# South America                 632  2434783.0   5986094.0  102851.0
# United States                 617  5503986.0  16582397.0  187502.0
# Western Europe                642  4873000.0  14842250.0  169755.0
#
#                            mean_Sales  mean_Returns
# Region
# ...

# %%
# Get the first 20 Products in terms of their returns
by_vars = ["Returns"]
top_20_prod = retail_df.sort_values(by = by_vars, ascending = False).reset_index(drop = True)
top_20_prod = top_20_prod[:20]

# Calculate the discount for top 20 products
# > 50,000 - 0.5
# Between 15,000 to 50,000 - 0.3
# Between 10,000 to 15,000 - 0.2
top_20_prod["Discount"] = np.where(top_20_prod[by_vars] >= 50000, 0.5,
                                  (np.where(top_20_prod[by_vars] >= 15000, 0.3, 0.2)))
top_20_prod
# top_20_prod["Discount"] = pd.cut(top_20_prod.Returns, [10000, 15000, 50000, np.inf], labels=[0.2,0.3,0.5])
# top_20_prod

# Calculate the Sales after discount
top_20_prod["Sales_after_discount"] = top_20_prod.Sales * top_20_prod.Discount
top_20_prod
# Out:
#                        Region         Product  Subsidiary  Stores      Sales  \
# 0                 Middle East    Men's Casual    Tel Aviv      11  1298717.0
# 1                      Canada         Slipper   Vancouver      27   700513.0
# 2                      Canada    Men's Casual   Vancouver      25   353361.0
# 3   Central America/Caribbean    Men's Casual    Kingston      28   576112.0
# 4                      Canada   Women's Dress   Vancouver      21   756347.0
# 5               United States    Men's Casual     Chicago      26   408978.0
# 6                 Middle East    Men's Casual       Dubai      29   419336.0
# 7              Western Europe  Women's Casual  Copenhagen      26   502636.0
# 8                 Middle East   Women's Dress    Tel Aviv      18   434496.0
# 9                      Canada     Men's Dress   Vancouver      28   757798.0
# 10  Central America/Caribbean         Slipper    Kingston      37   476638.0
# ...

# %%
# Merge the Top 20 Product adjusted sales (discounted sales) with original Retail dataframe
retail_df2 = retail_df.merge(top_20_prod, how = "left").fillna(0)
retail_df2["Sales_after_discount"] = np.where(retail_df2.Discount == 0, retail_df2.Sales, retail_df2.Sales_after_discount)
retail_df2 = retail_df2.sort_values(by = ["Returns"], ascending = False)
retail_df2
# Out:
#                         Region        Product Subsidiary  Stores      Sales  \
# 187                Middle East   Men's Casual   Tel Aviv      11  1298717.0
# 103                     Canada        Slipper  Vancouver      27   700513.0
# 100                     Canada   Men's Casual  Vancouver      25   353361.0
# 108  Central America/Caribbean   Men's Casual   Kingston      28   576112.0
# 106                     Canada  Women's Dress  Vancouver      21   756347.0
# ..                         ...            ...        ...     ...        ...
# 320              United States         Sandal   New York       1      554.0
# 69                        Asia     Sport Shoe      Tokyo       1     1155.0
# 204                    Pacific         Sandal   Canberra       1     1093.0
# 196                    Pacific         Sandal   Auckland       1      325.0
# 66                        Asia     Sport Shoe      Seoul       1      937.0
#
#      Inventory  Returns  Discount  Sales_after_discount
# ...

# %%
left:
    
retail_df:
    
product sales
A 100
B 200
C 300
D 400
E 500

right:
    
top_20_prod:
    
product adjusted_sales
A 50
B 100
C 150

output:

product sales adjusted_sales
A 100 50
B 200 100
C 300 150
D 400 0
E 500 0

# %%
# Read the Retail India dataset with header information
infile = "C:\\Users\\Urvish\\Data Science using SAS and Python\\Data\\Retail_India.csv"
retail_india_df = pd.read_csv(infile, delimiter = ",")
retail_india_df
# Out:
#   Region         Product Subsidiary  Stores  Sales  Inventory  Returns
# 0   Asia            Boot      India       1   1996       9576       80
# 1   Asia     Men's Dress      India       1   3033      20831       52
# 2   Asia          Sandal      India       1   3230      15087      120
# 3   Asia         Slipper      India       1   3019      16075      127
# 4   Asia  Women's Casual      India       1   5389      16251      185

# %%
# Append the Retail India Products to main dataframe
retail_df = retail_df.append(retail_india_df).reset_index(drop = True)
retail_df
# Out:
#      Region         Product   Subsidiary  Stores    Sales  Inventory  Returns
# 0    Africa            Boot  Addis Ababa      12  29761.0   191821.0    769.0
# 1    Africa    Men's Casual  Addis Ababa       4  67242.0   118036.0   2284.0
# 2    Africa     Men's Dress  Addis Ababa       7  76793.0   136273.0   2433.0
# 3    Africa          Sandal  Addis Ababa      10  62819.0   204284.0   1861.0
# 4    Africa         Slipper  Addis Ababa      14  68641.0   279795.0   1771.0
# ..      ...             ...          ...     ...      ...        ...      ...
# 395    Asia            Boot        India       1   1996.0     9576.0     80.0
# 396    Asia     Men's Dress        India       1   3033.0    20831.0     52.0
# 397    Asia          Sandal        India       1   3230.0    15087.0    120.0
# 398    Asia         Slipper        India       1   3019.0    16075.0    127.0
# 399    Asia  Women's Casual        India       1   5389.0    16251.0    185.0
#
# [400 rows x 7 columns]

# %%
# Specify the Name for Dataframe
retail_df.name = "Retail Dataframe"

# Get the Total/Sum of all the numeric variables across Region and Subsidiary from retail Dataframe
util_retail_aggr(in_dfn = retail_df, analysis_vars = "All", group_vars = ["Region","Subsidiary"])
# Out:
# Input Dataframe Name =  Retail Dataframe
# Analysis Variables =  All
# Grouping Variables =  ['Region', 'Subsidiary']
#                                         Stores      Sales  Inventory   Returns
# Region                    Subsidiary
# Africa                    Addis Ababa       65   467429.0  1356501.0   13370.0
#                           Algiers          101   395600.0  1212116.0   12763.0
#                           Cairo             88   738198.0  2245536.0   22477.0
#                           Johannesburg      51   113008.0   375534.0    3962.0
#                           Khartoum          71   186592.0   588019.0    7051.0
#                           Kinshasa          56   196816.0   591284.0    5582.0
#                           Luanda            30   138115.0   436277.0    4328.0
#                           Nairobi           70   106830.0   295806.0    4554.0
# Asia                      Bangkok            5    16667.0    77820.0     564.0
# ...
