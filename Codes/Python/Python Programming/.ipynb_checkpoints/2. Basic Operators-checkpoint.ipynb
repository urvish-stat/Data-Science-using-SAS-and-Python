# %% [markdown]
# # Basic Operators

# %%
# Python Arithmetic Operators
a = 20
b = 10
c = 0

c = a + b
print('Line 1 - Value of c is ', c)

c = a - b
print('Line 2 - Value of c is ', c)

c = a * b
print('Line 3 - Value of c is ', c)

c = a/b
print('Line 4 - Value of c is ', c)

c = a % b
print('Line 5 - Value of c is ', c)

a = 2
b = 3
c = a**b
print('Line 6 - Value of c is ', c)
# Out:
# Line 1 - Value of c is  30
# Line 2 - Value of c is  10
# Line 3 - Value of c is  200
# Line 4 - Value of c is  2.0
# Line 5 - Value of c is  0
# Line 6 - Value of c is  8

# %%
# Python Comparison Operators
a = 20
b = 10
if a == b:    
    print('Line 1 - a is equal to b')
else:
    print('Line 1 - a is not equal to b')

if a != b:
    print('Line 2 - a is not equal to b')
else:
    print('Line 2 - a is equal to b')

if a < b:
    print('Line 3 - a is less than b')
else:
    print('Line 3 - a is not less than b')

if a > b:
    print('Line 4 - a is greater than b')
else:
    print('Line 4 - a is not greater than b')

if a >= b:
    print('Line 5 - a is greater than equal to b')
else:
    print('Line 5 - a is not greater than equal b')

if a <= b:
    print('Line 6 - a is less than equal to b')
else:
    print('Line 6 - a is not less than equal to b')
# Out:
# Line 1 - a is not equal to b
# Line 2 - a is not equal to b
# Line 3 - a is not less than b
# Line 4 - a is greater than b
# Line 5 - a is greater than equal to b
# Line 6 - a is not less than equal to b

# %%
# Python Assignment Operators
a = 21
b = 10
c = 0

c = a + b
c += b

print('Line 1 - Value of c is ', c)

c *= a 
print('Line 2 - Value of c is ', c)

c /= a
print('Line 3 - Value of c is ', c)

c = 2
c %= a
print('Line 4 - Value of c is ', c)

c **= a
print('Line 5 - Value of c is ', c)
# Out:
# Line 1 - Value of c is  41
# Line 2 - Value of c is  861
# Line 3 - Value of c is  41.0
# Line 4 - Value of c is  2
# Line 5 - Value of c is  2097152

# %%
# Python Membership Operators
a = 10
b = 20
list1 = list(range(1,6))
print(list1)

if a in list1:
    print('Line 1 - Value of a is available in list')
else:
    print('Line 1 - Value of a is not available in list')

if b not in list1:
    print('Line 2 - Value of b is not in list')
else:
    print('Line 2 - Value of b is in list')

c = b/a
if c in list1:
    print('Line 3 - Value of c is in list')
else:
    print('Line 3 - Value of c is not in list')
# Out:
# [1, 2, 3, 4, 5]
# Line 1 - Value of a is not available in list
# Line 2 - Value of b is not in list
# Line 3 - Value of c is in list
